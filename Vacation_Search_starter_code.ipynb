# %% [markdown]
# # Deliverable 2. Create a Customer Travel Destinations Map
#
# ----
#
# 1. Create a folder called `Vacation_Search` to save all the files related with this deliverable.
#
# 2. Download the `Vacation_Search_starter_code.ipynb` Jupyter notebook,save it into your `Vacation_Search folder`, and rename it as `Vacation_Search.ipynb`.
#
# 3. In the `Vacation_Search.ipynb` file, ensure that the dependencies and the Geoapify API key is imported correctly.
#
# 4. From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`.
#
# 5. Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.
#
# 6. Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`.
#
# 7. Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.
#
# 8. Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".
#
# 9. Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.
#
# 10. Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.
#
# 11. Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found".
#
# 12. Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.
#
# 13. Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.
#
# 14. Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame. In the point for each city add:
#
#     * The city name
#
#     * The country code
#
#     * The weather description
#
#     * The point's size should be the maximum temperature for the city
#
# 15. Take a screenshot of your map and save it to the `Vacation_Search` folder as `WeatherPy_vacation_map.png`.
#
# ---

# %% [markdown]
# ## Ensure that the dependencies and the Geoapify API key is imported correctly

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from config import geoapify_key

# %% [markdown]
# ## From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`

# %%
# Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv('WeatherPy_Database.csv')



# Display sample data
city_data_df.head(10)
# Out:
#    City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0         vaini      TO -21.2000 -175.2000     84.36        74
# 1        1     cape town      ZA -33.9258   18.4232     76.37        74
# 2        2   tuktoyaktuk      CA  69.4541 -133.0374     -0.40        85
# 3        3          ayan      RU  56.4500  138.1667    -33.34        75
# 4        4        castro      BR -24.7911  -50.0119     66.43        93
# 5        5        lenger      KZ  42.1830   69.8839      8.04        56
# 6        6        dikson      RU  73.5069   80.5464    -17.36        82
# 7        7       rikitea      PF -23.1203 -134.9692     78.69        69
# 8        8  punta arenas      CL -53.1500  -70.9167     62.71        48
# 9        9        lompoc      US  34.6391 -120.4579     61.02        69
#
#    Cloudiness  Wind Speed Current Description
# 0          75        5.75          light rain
# 1           0        1.14           clear sky
# 2         100        9.22                mist
# 3          53        7.14       broken clouds
# 4          91        3.49     overcast clouds
# 5           0        7.83           clear sky
# 6         100        7.34     overcast clouds
# 7         100        4.76     overcast clouds
# 8           0       26.46           clear sky
# 9          20       13.80          few clouds

# %% [markdown]
# ## Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation

# %%
# Prompt the user to enter minimum and maximum temperature criteria.
min_temp = float(input("What is the minimum temperature you would like for your trip?"))
max_temp = float(input("What is the maximum temperature you would like for your trip?"))
# Out:
# What is the minimum temperature you would like for your trip?60
# What is the maximum temperature you would like for your trip?100

# %% [markdown]
# ## Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`

# %%
# Filter the city_data_df DataFrame to find the cities that fit the criteria using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] >= min_temp) &
                                       (city_data_df["Max Temp"] <= max_temp)]





# # Display sample data
preferred_cities_df.head(10)
# Out:
#     City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 0         0         vaini      TO -21.2000 -175.2000     84.36        74
# 1         1     cape town      ZA -33.9258   18.4232     76.37        74
# 4         4        castro      BR -24.7911  -50.0119     66.43        93
# 7         7       rikitea      PF -23.1203 -134.9692     78.69        69
# 8         8  punta arenas      CL -53.1500  -70.9167     62.71        48
# 9         9        lompoc      US  34.6391 -120.4579     61.02        69
# 11       11          hilo      US  19.7297 -155.0900     80.33        78
# 12       12     mahebourg      MU -20.4081   57.7000     78.26        85
# 14       14    nouadhibou      MR  20.9310  -17.0347     69.78        52
# 16       16        domoni      KM -12.2569   44.5319     78.22        85
#
#     Cloudiness  Wind Speed Current Description
# 0           75        5.75          light rain
# 1            0        1.14           clear sky
# 4           91        3.49     overcast clouds
# 7          100        4.76     overcast clouds
# 8            0       26.46           clear sky
# 9           20       13.80          few clouds
# 11         100       14.97     overcast clouds
# 12          91       19.66          light rain
# 14          99       19.57     overcast clouds
# 16          98        2.86          light rain

# %% [markdown]
# ## Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows

# %%
# Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_travel_cities = preferred_cities_df.dropna()


# # Display sample data
clean_travel_cities
# Out:
#      City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 0          0         vaini      TO -21.2000 -175.2000     84.36        74
# 1          1     cape town      ZA -33.9258   18.4232     76.37        74
# 4          4        castro      BR -24.7911  -50.0119     66.43        93
# 7          7       rikitea      PF -23.1203 -134.9692     78.69        69
# 8          8  punta arenas      CL -53.1500  -70.9167     62.71        48
# ..       ...           ...     ...      ...       ...       ...       ...
# 663      663     caravelas      BR -17.7125  -39.2481     75.74        84
# 664      664      chabahar      IR  25.2919   60.6430     68.49        57
# 665      665          uige      AO  -7.6087   15.0613     64.72        96
# 669      669    natitingou      BJ  10.3042    1.3796     72.99        19
# 672      672       pitimbu      BR  -7.4706  -34.8086     75.79        80
#
#      Cloudiness  Wind Speed Current Description
# 0            75        5.75          light rain
# 1             0        1.14           clear sky
# 4            91        3.49     overcast clouds
# 7           100        4.76     overcast clouds
# 8             0       26.46           clear sky
# ..          ...         ...                 ...
# 663          48        4.97    scattered clouds
# 664          10        7.16           clear sky
# 665          52        2.68       broken clouds
# 669           6        7.27           clear sky
# 672         100       10.69          light rain
#
# [331 rows x 10 columns]

# %% [markdown]
# ## Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng"

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_travel_cities[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# %% [markdown]
# ## Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame

# %%
# Create a new column "Hotel Name".
hotel_df["Hotel Name"] = " "

# Display sample data
hotel_df.head(20)
# Out:
#                  City Country  Max Temp Current Description      Lat  \
# 0               vaini      TO     84.36          light rain -21.2000
# 1           cape town      ZA     76.37           clear sky -33.9258
# 4              castro      BR     66.43     overcast clouds -24.7911
# 7             rikitea      PF     78.69     overcast clouds -23.1203
# 8        punta arenas      CL     62.71           clear sky -53.1500
# 9              lompoc      US     61.02          few clouds  34.6391
# 11               hilo      US     80.33     overcast clouds  19.7297
# 12          mahebourg      MU     78.26          light rain -20.4081
# 14         nouadhibou      MR     69.78     overcast clouds  20.9310
# 16             domoni      KM     78.22          light rain -12.2569
# 18         codrington      AU     60.13     overcast clouds -38.2667
# 21            mataura      NZ     71.02          few clouds -46.1927
# 22            cayenne      GF     77.04     overcast clouds   4.9333
# 26           coquimbo      CL     69.53           clear sky -29.9533
# 28        grand gaube      MU     78.39          light rain -20.0064
# 29  valle de banderas      MX     76.60       broken clouds  20.8000
# 31            ushuaia      AR     60.46          light rain -54.8000
# 33             hobart      AU     66.06       broken clouds -42.8794
# 36         bredasdorp      ZA     69.91     overcast clouds -34.5322
# 37            bintulu      MY     73.81          few clouds   3.1667
#
#          Lng Hotel Name
# 0  -175.2000
# 1    18.4232
# 4   -50.0119
# 7  -134.9692
# 8   -70.9167
# 9  -120.4579
# 11 -155.0900
# 12   57.7000
# 14  -17.0347
# 16   44.5319
# 18  141.9667
# 21  168.8643
# 22  -52.3333
# 26  -71.3436
# 28   57.6608
# 29 -105.2333
# 31  -68.3000
# 33  147.3294
# 36   20.0403
# 37  113.0333

# %% [markdown]
# ## Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city

# %%
# Set parameters to search for a hotel
radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

# %% [markdown]
# ## Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found"

# %%
# Iterate through the hotel DataFrame

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set up the base URL for the Geoapify Places API.
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionaty
    # Convert the API response to JSON format
    name_address = requests.get(base_url, params=params).json()
    
    
   
    
    # Get the first hotel from the results and store the name, if a hotel isn't found set the hotel name as "No hotel found".
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# vaini - nearest hotel: Keleti International Resort
# cape town - nearest hotel: Townhouse Hotel
# castro - nearest hotel: Hotel Central Palace
# rikitea - nearest hotel: Chez Bianca & Benoit
# punta arenas - nearest hotel: Hotel Lacolet
# lompoc - nearest hotel: Embassy Suites by Hilton Lompoc Central Coast
# hilo - nearest hotel: Dolphin Bay Hotel
# mahebourg - nearest hotel: Grand Bel Air
# nouadhibou - nearest hotel: Hotel valencia
# domoni - nearest hotel: Hotel Djadid
# codrington - nearest hotel: No hotel found
# mataura - nearest hotel: No hotel found
# cayenne - nearest hotel: Central Hôtel
# coquimbo - nearest hotel: Hotel Iberia
# grand gaube - nearest hotel: Coco Villa
# valle de banderas - nearest hotel: No hotel found
# ushuaia - nearest hotel: Apart Hotel Aires del Beagle
# hobart - nearest hotel: Vibe Hotel Hobart
# bredasdorp - nearest hotel: Victoria Hotel
# bintulu - nearest hotel: Bakun Inn
# emerald - nearest hotel: Emerald Central Hotel
# longido - nearest hotel: No hotel found
# santa cruz - nearest hotel: Aviador Hotel Boutique
# mpongwe - nearest hotel: No hotel found
# port lincoln - nearest hotel: Boston Hotel
# port alfred - nearest hotel: No hotel found
# hambantota - nearest hotel: Oasis Aurweda Resort Hambathota
# sao felix do xingu - nearest hotel: Hotel Terraço
# te anau - nearest hotel: Lakeside Motels & Apartments
# hermanus - nearest hotel: Aloe guest house
# mana - nearest hotel: Le Samana
# puerto ayora - nearest hotel: Hostal La Mirada De Solitario George
# tshela - nearest hotel: No hotel found
# kavieng - nearest hotel: Kavieng Hotel
# souillac - nearest hotel: Hotel SkylineInn
# new norfolk - nearest hotel: Woodbridge on the Derwent
# atuona - nearest hotel: Pearl Resort
# geraldton - nearest hotel: Ocean Centre Hotel
# saint-philippe - nearest hotel: Le Baril
# padang - nearest hotel: losmen Surya
# sola - nearest hotel: No hotel found
# luanda - nearest hotel: Hotel Forum
# chuy - nearest hotel: Alerces
# bonfim - nearest hotel: No hotel found
# cabo san lucas - nearest hotel: Comfort Rooms
# asosa - nearest hotel: Africa Hotel
# veraval - nearest hotel: Shyam
# labuhan - nearest hotel: No hotel found
# hobyo - nearest hotel: No hotel found
# alyangula - nearest hotel: No hotel found
# hope - nearest hotel: Best Western
# port elizabeth - nearest hotel: Waterford Hotel
# mathathane - nearest hotel: No hotel found
# flinders - nearest hotel: No hotel found
# tessalit - nearest hotel: No hotel found
# iquique - nearest hotel: Hostal Vivar
# cidreira - nearest hotel: Hotel Castelo
# mahibadhoo - nearest hotel: Coral View Inn
# bambous virieux - nearest hotel: No hotel found
# tuatapere - nearest hotel: No hotel found
# kahului - nearest hotel: Maui Seaside Hotel
# bangui - nearest hotel: Hotel Levy's
# kapaa - nearest hotel: Pono Kai Resort
# huarmey - nearest hotel: Hostal Santa Rosa
# kiunga - nearest hotel: No hotel found
# lebu - nearest hotel: No hotel found
# avarua - nearest hotel: Paradise Inn
# talcahuano - nearest hotel: Club Recreativo Armada de Chile
# constitucion - nearest hotel: Hostal Alameda
# faanui - nearest hotel: Oa Oa Lodge
# tiarei - nearest hotel: No hotel found
# espinosa - nearest hotel: No hotel found
# isabela - nearest hotel: No hotel found
# barra do garcas - nearest hotel: Pousada Portal
# pisco - nearest hotel: La Portada
# vanimo - nearest hotel: CBC Guesthouse
# samana - nearest hotel: Hotel Cotubanamá
# mar del plata - nearest hotel: Nuevo Ostende
# paita - nearest hotel: Victor's
# bluff - nearest hotel: No hotel found
# bubaque - nearest hotel: Chez Julio
# bumba - nearest hotel: No hotel found
# marshall - nearest hotel: No hotel found
# san jose - nearest hotel: Hotel De Anza
# ahipara - nearest hotel: YHA Ahipara
# beruwala - nearest hotel: Villa@113
# ambilobe - nearest hotel: Hôtel National
# hualmay - nearest hotel: Hotel Mi Choacan
# thinadhoo - nearest hotel: No hotel found
# mapiripan - nearest hotel: No hotel found
# makakilo city - nearest hotel: Embassy Suites by Hilton Oahu Kapolei
# port macquarie - nearest hotel: The Observatory
# raga - nearest hotel: No hotel found
# carnarvon - nearest hotel: No hotel found
# butaritari - nearest hotel: No hotel found
# meulaboh - nearest hotel: Hotel Meuligou
# talara - nearest hotel: Hospedaje El Aypate
# yeppoon - nearest hotel: Blossom's on Seaspray
# vila velha - nearest hotel: Hotel Prainha
# kaitangata - nearest hotel: No hotel found
# kasempa - nearest hotel: Kasmpa Council Guest House
# santiago del estero - nearest hotel: Nuevo Hotel Brístol
# sao filipe - nearest hotel: Bela Vista
# georgetown - nearest hotel: Page 63 hostel
# pontian kecil - nearest hotel: Hotel Wan Loong
# pemangkat - nearest hotel: Hotel Kelapa Gading
# richards bay - nearest hotel: Protea Hotel
# kavaratti - nearest hotel: No hotel found
# najran - nearest hotel: No hotel found
# salalah - nearest hotel: Muscat International Hotel
# sal rei - nearest hotel: Hotel Marine Club
# kainantu - nearest hotel: Kainantu Lodge
# hoi an - nearest hotel: No hotel found
# ponta do sol - nearest hotel: Estalagem Ponta do Sol
# saint-pierre - nearest hotel: Tropic Hotel
# broken hill - nearest hotel: Ibis Styles
# san patricio - nearest hotel: No hotel found
# port-gentil - nearest hotel: Tara-Mé
# reo - nearest hotel: No hotel found
# bengkulu - nearest hotel: Dena Hotel
# barao de melgaco - nearest hotel: No hotel found
# chauk - nearest hotel: Royal Chauk
# port blair - nearest hotel: Andaman Ocean Breeze
# maldonado - nearest hotel: No hotel found
# benguela - nearest hotel: Hotel Moibela
# aloleng - nearest hotel: No hotel found
# touros - nearest hotel: Pousada Atlântico
# west monroe - nearest hotel: Wingate
# warri - nearest hotel: Warri Sapele Road
# neuquen - nearest hotel: Hotel Argentina 307
# hithadhoo - nearest hotel: Pebbles Inn
# yaan - nearest hotel: No hotel found
# mersing - nearest hotel: Mersing Inn Hotel
# cristalina - nearest hotel: Goyás
# whyalla - nearest hotel: Whyalla Playford Apartments
# kirakira - nearest hotel: No hotel found
# rio bueno - nearest hotel: No hotel found
# nazareno - nearest hotel: No hotel found
# san pedro - nearest hotel: Hotel Takara
# mocuba - nearest hotel: No hotel found
# yenagoa - nearest hotel: Peretimi Hotels Ltd.
# porto novo - nearest hotel: Hôtel 6500 CFA
# santa rosa - nearest hotel: JARS RESORT
# mareeba - nearest hotel: The Gateway Hotel
# gigmoto - nearest hotel: No hotel found
# durango - nearest hotel: No hotel found
# kasane - nearest hotel: Kasane Travel Lodge
# talusan - nearest hotel: No hotel found
# paoua - nearest hotel: No hotel found
# santa luzia - nearest hotel: Alcoboca
# mbinga - nearest hotel: No hotel found
# sarangarh - nearest hotel: No hotel found
# celestun - nearest hotel: Hotel Flamingo Playa
# cotonou - nearest hotel: BENIN ROYAL HOTEL
# cruzeiro do sul - nearest hotel: Estrela Palace Hotel
# oxapampa - nearest hotel: Yanachaga
# pemba - nearest hotel: Hotel Rafael
# arraial do cabo - nearest hotel: No hotel found
# cururupu - nearest hotel: No hotel found
# mpulungu - nearest hotel: No hotel found
# tual - nearest hotel: Suita
# gushikawa - nearest hotel: No hotel found
# katete - nearest hotel: No hotel found
# honiara - nearest hotel: King Solomon Hotel
# nizwa - nearest hotel: Nizwa Heritage Inn
# tibati - nearest hotel: No hotel found
# port moresby - nearest hotel: The Sanctuary Hotel and Spa
# whitianga - nearest hotel: No hotel found
# east london - nearest hotel: No hotel found
# plettenberg bay - nearest hotel: Milkwood Manor
# mogadishu - nearest hotel: SYL Hotel
# thaton - nearest hotel: Thuwunnabumi Hotel
# kaeo - nearest hotel: No hotel found
# praya - nearest hotel: Casa Sodadi
# port keats - nearest hotel: No hotel found
# lucea - nearest hotel: Blue Paloma Bed And Breakfast
# camacha - nearest hotel: Praia Dourada
# airai - nearest hotel: No hotel found
# kampong cham - nearest hotel: Phnom Pros Hotel
# paciran - nearest hotel: No hotel found
# esperance - nearest hotel: Hospitality
# doljo - nearest hotel: Bellevue Resort Panglao
# viedma - nearest hotel: Níjar
# alta floresta - nearest hotel: Villas Hotel
# kiama - nearest hotel: Nova Kiama
# rakaia - nearest hotel: No hotel found
# avera - nearest hotel: No hotel found
# corowa - nearest hotel: No hotel found
# mimongo - nearest hotel: No hotel found
# monrovia - nearest hotel: Bella Casa Hotel
# bathsheba - nearest hotel: Atlantis Hotel
# bodden town - nearest hotel: Turtle Nest Inn
# san carlos de bariloche - nearest hotel: Kronos
# dekar - nearest hotel: No hotel found
# surt - nearest hotel: فندق المدينة-سرت
# alofi - nearest hotel: No hotel found
# tautira - nearest hotel: No hotel found
# soyo - nearest hotel: Hotel Maria Teres
# kudahuvadhoo - nearest hotel: No hotel found
# diu - nearest hotel: Hotel Ankur
# taoudenni - nearest hotel: No hotel found
# mbour - nearest hotel: Keur Sarafina Mbour
# villa carlos paz - nearest hotel: Hoterl Victor
# parkes - nearest hotel: Commercial Hotel
# izmir - nearest hotel: Elara Hotel
# maceio - nearest hotel: Maceió Hostel e Pousada
# marawi - nearest hotel: Marawi Resort Hotel
# ormara - nearest hotel: No hotel found
# kununurra - nearest hotel: Kununurra Country Club Resort
# taltal - nearest hotel: Hostería Taltal
# namatanai - nearest hotel: Namatanai Hotel
# nelson bay - nearest hotel: No hotel found
# bachaquero - nearest hotel: No hotel found
# pozo colorado - nearest hotel: No hotel found
# boda - nearest hotel: No hotel found
# bandar-e lengeh - nearest hotel: Old owner do not like foreigners hotel
# isangel - nearest hotel: Tanna Lodge
# coihaique - nearest hotel: No hotel found
# umm lajj - nearest hotel: No hotel found
# asfi - nearest hotel: Golden Tulip Farah Safi
# touba - nearest hotel: No hotel found
# san cristobal - nearest hotel: Terra Sur
# nakhon thai - nearest hotel: Chantuk Resort
# saldanha - nearest hotel: Hoedjesbaai
# kalmunai - nearest hotel: Saji new food
# menongue - nearest hotel: No hotel found
# basco - nearest hotel: Tawsen Hotel
# caucaia - nearest hotel: No hotel found
# ouesso - nearest hotel: Auberge Nianina
# manzanillo - nearest hotel: Hotel Venus
# lahij - nearest hotel: No hotel found
# benghazi - nearest hotel: ترجاب
# lufilufi - nearest hotel: No hotel found
# charlestown - nearest hotel: Warners Bay Hotel
# anloga - nearest hotel: Hotel de White House
# belmonte - nearest hotel: No hotel found
# puerto del rosario - nearest hotel: Hotel Tamasite
# houma - nearest hotel: Courtyard by Marriott Houma
# ahuimanu - nearest hotel: No hotel found
# gambo - nearest hotel: No hotel found
# inhambane - nearest hotel: Hotel de Inhambane
# calama - nearest hotel: Apart Hotel Geotel Calama
# nhulunbuy - nearest hotel: No hotel found
# byron bay - nearest hotel: Lord Byron Resort
# nabire - nearest hotel: Hotel Anggrek
# antalaha - nearest hotel: Hôtel Florida
# sao raimundo nonato - nearest hotel: Pousada Zabelê
# kruisfontein - nearest hotel: No hotel found
# campo grande - nearest hotel: Hotel Metropolitan
# santa maria - nearest hotel: Hotel Morotin
# qeshm - nearest hotel: هتل آپادانا
# hwange - nearest hotel: No hotel found
# boma - nearest hotel: No hotel found
# karratha - nearest hotel: Karratha International Hotel
# lorengau - nearest hotel: Seeadler Bay Hotel
# kupang - nearest hotel: BIB & LANG GUEST HOUSE
# bilma - nearest hotel: No hotel found
# punto fijo - nearest hotel: Hotel Caribe
# dosso - nearest hotel: Galaxy Hotel
# doctor juan leon mallorquin - nearest hotel: No hotel found
# koutiala - nearest hotel: La Chaumière
# stephenville - nearest hotel: No hotel found
# kieta - nearest hotel: No hotel found
# kita - nearest hotel: Hotel Chats Rouges
# le vauclin - nearest hotel: Hôtel Macabou
# adrar - nearest hotel: No hotel found
# auki - nearest hotel: No hotel found
# camocim - nearest hotel: Hotel Camocim
# waipawa - nearest hotel: No hotel found
# dire dawa - nearest hotel: Adis Abeba
# sijunjung - nearest hotel: Hotel Bukik Gadang
# puerto leguizamo - nearest hotel: Hotel Girasoles
# ancud - nearest hotel: Cabañas
# san ignacio - nearest hotel: Rainforest Haven Inn
# vao - nearest hotel: Nataiwatch
# palmas - nearest hotel: Hotel Triângulo Mineiro
# chokwe - nearest hotel: Limpopo Hotel
# salinopolis - nearest hotel: Hotel Salinópolis
# zabid - nearest hotel: No hotel found
# hadejia - nearest hotel: No hotel found
# inongo - nearest hotel: Chez LELE IYOLO
# rio gallegos - nearest hotel: Amérian Río Gallegos Apart & Suites
# kovur - nearest hotel: No hotel found
# upata - nearest hotel: Hotel Garibardi
# beloha - nearest hotel: No hotel found
# chongwe - nearest hotel: No hotel found
# wodonga - nearest hotel: Quest Apartments
# tanhacu - nearest hotel: Tanhaçu Palace
# san vicente de canete - nearest hotel: Hotel Colibrí
# nishihara - nearest hotel: ユインチホテル南城
# goma - nearest hotel: Hôtel Case Depart
# qui nhon - nearest hotel: No hotel found
# yulara - nearest hotel: Outback Pioneer Hotel & Lodge
# libreville - nearest hotel: No hotel found
# bourail - nearest hotel: Hôtel Restaurant La Néra
# samarai - nearest hotel: No hotel found
# machinga - nearest hotel: No hotel found
# port augusta - nearest hotel: Hotel Commonwealth
# rantepao - nearest hotel: Hotel Indra Toraja
# kudat - nearest hotel: Hotel Ria
# sao jose da coroa grande - nearest hotel: Hotel do Sol
# prado - nearest hotel: Pousada Recanto do Prado
# jiwani - nearest hotel: No hotel found
# noumea - nearest hotel: Hotel Gondwana
# manggar - nearest hotel: No hotel found
# merauke - nearest hotel: No hotel found
# grajau - nearest hotel: Torre Palace Hotel
# buluang - nearest hotel: No hotel found
# clarence town - nearest hotel: Erringhi Hotel
# pout - nearest hotel: No hotel found
# cockburn town - nearest hotel: The Salt Raker Inn
# acapulco - nearest hotel: Hotel del Valle
# catamarca - nearest hotel: Hotel de Turismo
# victoria point - nearest hotel: Seminara Appartments
# dennery - nearest hotel: No hotel found
# mitsamiouli - nearest hotel: Hotel le Paradis
# muncar - nearest hotel: No hotel found
# kampot - nearest hotel: Sambor Sambat Guesthouse
# adre - nearest hotel: No hotel found
# pocone - nearest hotel: Andirah
# gouloure - nearest hotel: No hotel found
# lotofaga - nearest hotel: No hotel found
# niquelandia - nearest hotel: Serrano Hotel
# sumenep - nearest hotel: No hotel found
# rawson - nearest hotel: Hotel Deportivo
# cabedelo - nearest hotel: No hotel found
# caravelas - nearest hotel: Pousada dos Navegantes
# chabahar - nearest hotel: هتل سپیده
# uige - nearest hotel: No hotel found
# natitingou - nearest hotel: CPNO
# pitimbu - nearest hotel: Pousada Brisa Mar
#              City Country  Max Temp Current Description      Lat       Lng  \
# 0           vaini      TO     84.36          light rain -21.2000 -175.2000
# 1       cape town      ZA     76.37           clear sky -33.9258   18.4232
# 4          castro      BR     66.43     overcast clouds -24.7911  -50.0119
# 7         rikitea      PF     78.69     overcast clouds -23.1203 -134.9692
# 8    punta arenas      CL     62.71           clear sky -53.1500  -70.9167
# ..            ...     ...       ...                 ...      ...       ...
# 663     caravelas      BR     75.74    scattered clouds -17.7125  -39.2481
# 664      chabahar      IR     68.49           clear sky  25.2919   60.6430
# 665          uige      AO     64.72       broken clouds  -7.6087   15.0613
# 669    natitingou      BJ     72.99           clear sky  10.3042    1.3796
# 672       pitimbu      BR     75.79          light rain  -7.4706  -34.8086
#
#                       Hotel Name
# 0    Keleti International Resort
# 1                Townhouse Hotel
# 4           Hotel Central Palace
# 7           Chez Bianca & Benoit
# 8                  Hotel Lacolet
# ..                           ...
# 663       Pousada dos Navegantes
# 664                    هتل سپیده
# 665               No hotel found
# 669                         CPNO
# 672            Pousada Brisa Mar
#
# [331 rows x 7 columns]

# %% [markdown]
# ## Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`

# %%
# Drop the rows where there is no Hotel Name
clean_hotel_df = hotel_df.dropna(axis="index", how="any")

# Display sample data
clean_hotel_df
# Out:
#              City Country  Max Temp Current Description      Lat       Lng  \
# 0           vaini      TO     84.36          light rain -21.2000 -175.2000
# 1       cape town      ZA     76.37           clear sky -33.9258   18.4232
# 4          castro      BR     66.43     overcast clouds -24.7911  -50.0119
# 7         rikitea      PF     78.69     overcast clouds -23.1203 -134.9692
# 8    punta arenas      CL     62.71           clear sky -53.1500  -70.9167
# ..            ...     ...       ...                 ...      ...       ...
# 663     caravelas      BR     75.74    scattered clouds -17.7125  -39.2481
# 664      chabahar      IR     68.49           clear sky  25.2919   60.6430
# 665          uige      AO     64.72       broken clouds  -7.6087   15.0613
# 669    natitingou      BJ     72.99           clear sky  10.3042    1.3796
# 672       pitimbu      BR     75.79          light rain  -7.4706  -34.8086
#
#                       Hotel Name
# 0    Keleti International Resort
# 1                Townhouse Hotel
# 4           Hotel Central Palace
# 7           Chez Bianca & Benoit
# 8                  Hotel Lacolet
# ..                           ...
# 663       Pousada dos Navegantes
# 664                    هتل سپیده
# 665               No hotel found
# 669                         CPNO
# 672            Pousada Brisa Mar
#
# [331 rows x 7 columns]

# %% [markdown]
# ## Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the `Vacation_Search`` folder

# %%
# Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv"

# Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="city_ID")

# %% [markdown]
# ## Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame.
#
# In the point for each city add:
#
# * The city name
# * The country code
# * The weather description
# * The point's size should be the maximum temperature for the city

# %%
# Configure the map plot
hotel_df = clean_hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 1,
    color = "City",
    hover_cols = ["Hotel Name", "Country", "Current Description"]
)
# Display the map plot
hotel_df
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Hotel Name,Country,Current Description)
